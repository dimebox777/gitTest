# %%
import pandas as pd

import requests


df = pd.read_csv("orders.csv")

# %%
##df.head()
##df.tail()
##df.info()
##df.describe()
df.columns
##df.index
# Out:
# Index(['OrderID', 'CustomerName', 'Product', 'Category', 'Quantity', 'Price',
#        'OrderDate', 'Shipped', 'Country'],
#       dtype='object')

# %%
##len(df["Country"].unique())

len(set(df["Country"]))
# Out:
# 28

# %%
df[["Country","Product"]]

##df.iloc[0]

# %%
##filter dataframe

df[(df["Category"] == 'Electronics') & (df["Country"] == 'USA')]
##len(df[(df["Category"] == 'Electronics')])
# Out:
#    OrderID CustomerName Product     Category  Quantity   Price   OrderDate  \
# 0     1001   John Smith  Laptop  Electronics         1  1200.0  2024-06-01
#
#   Shipped Country
# 0     Yes     USA

# %%
df['Price'].mean()
df['Category'].unique()
# Out:
# array(['Electronics', 'Furniture', 'Stationery'], dtype=object)

# %%
df["Category"].unique()

df[df["Category"].isin(['Electronics'])]
df[~df["Category"].isin(['Electronics'])]

##keywords = ['Electronics', 'Furniture']
keywords = ['Furniture']
##keywords = ['Chair']

pattern = '|'.join(keywords)

filtered_df = df[df["Category"].str.contains(pattern, na=False)]
print(len(filtered_df))

##price_ave_by_country = df.groupby('Category')['Price'].mean()
##price_ave_by_country = df.groupby(['Category', 'Country'])['Price'].mean()
price_ave = filtered_df.groupby(['Category', 'Country'])['Price'].mean()
price_ave_cat = filtered_df.groupby(['Category'])['Price'].mean()



##print(price_ave)
##print(price_ave_cat)

##update df

df.loc[df["Category"] == 'Furniture', "Category"] == "Furn"
##print(df)
##df['Category'].unique()
# Out:
# 14

# %%
##df.loc[df["Category"] == 'Furniture', "Category"] == "Furn"

##df['Category'] = df['Category'].replace('Furniture', 'Furn')

# %%
df['Category'] = df['Category'].replace('Furn', 'Furniture')

# %%
df.loc[df["Category"] == 'Furniture']

# %%
df['O_date'] = pd.to_datetime(df["OrderDate"])

# %%
##df.groupby(['Category', pd.Grouper(key='O_date', freq='Y')])['Product'].size()
##df.groupby(['Category', df['O_date'].dt.to_period('M')]).size().reset_index(name='Count')
##df.groupby(['Category', df['O_date'].dt.to_period('M')])['Price'].mean()


##df.groupby(['Category', df['O_date'].dt.month])['Price'].mean()

##df.groupby(['Category', df['O_date'].dt.month_name()])['Price'].mean().sort_index()

month_order = [
    "January", "February", "March", "April", "May", "June",
    "July", "August", "September", "October", "November", "December"
]

df['month_name'] = pd.Categorical(
    df['O_date'].dt.month_name(),
    categories=month_order,
    ordered=True
)


##df.groupby(['Category', df['O_date'].dt.month_name(locale='en_US.utf8')])['Price'].mean()

##price_ave_year = df.groupby(['Category', 'Country'])['Price'].mean()

##df1 = df.groupby(df['O_date'].dt.to_period('M')).size()
##df['O_date']
##print(df1)

# %%
df.dropna()
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 0      1001        John Smith                 Laptop  Electronics         1
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# 11     1012         Raj Patel           File Cabinet    Furniture         2
# 27     2.5  2024-06-29     Yes        Russia 2024-06-29       June
# 28   110.0  2024-06-30     Yes   South Korea 2024-06-30       June
# 29    18.0  2024-07-01      No         Italy 2024-07-01       July
# 30    32.0  2024-07-02     Yes       Morocco 2024-07-02       July
# 31   140.0  2024-07-03     Yes       Germany 2024-07-03       July
# 32    42.0  2024-07-04      No      Colombia 2024-07-04       July
# 33     0.8  2024-07-05     Yes           USA 2024-07-05       July
# 34    55.0  2024-07-06     Yes         Japan 2024-07-06       July
# 35    68.0  2024-07-07      No            UK 2024-07-07       July
# 36   125.0  2024-07-08     Yes      Portugal 2024-07-08       July
# 37    28.0  2024-07-09     Yes          Iran 2024-07-09       July
# 38    18.0  2024-07-10      No   South Korea 2024-07-10       July
# 39    35.0  2024-07-11     Yes       Ukraine 2024-07-11       July

# %%
df.groupby(['Category', 'month_name' ])['Price'].mean().reset_index(name='Average').dropna()
# Out:
# /var/folders/ff/4qwktjyd3wj5njzx2mvpy2qc0000gn/T/ipykernel_3590/1257888415.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['Category', 'month_name' ])['Price'].mean().reset_index(name='Average').dropna()
#        Category month_name     Average
# 5   Electronics       June  166.384615
# 6   Electronics       July   74.000000
# 17    Furniture       June  166.333333
# 18    Furniture       July   38.200000
# 29   Stationery       June    5.214286
# 30   Stationery       July    0.800000

# %%
##df.groupby(['Category', 'month_name' ])['Price'].sum().reset_index(name='Sum')



##df['Price'] / df.groupby('Category')['Price'].transform('sum')

##state_office = df.groupby(['Category', 'Country']).agg({'Price': 'sum'})
state_office = df.groupby(['Category']).agg({'Price': 'sum'})
# Change: groupby state_office and divide by sum
state_pcts = state_office.groupby(level=0).apply(lambda x:100 * x / float(x.sum()))

print(state_office)
# Out:
#               Price
# Category
# Electronics  2533.0
# Furniture    1688.0
# Stationery     37.3
# /var/folders/ff/4qwktjyd3wj5njzx2mvpy2qc0000gn/T/ipykernel_3590/3356984989.py:10: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   state_pcts = state_office.groupby(level=0).apply(lambda x:100 * x / float(x.sum()))

# %%
##df2 = df.groupby(['Category']).agg({'Price': 'sum'})
##print(df2)
df2 = df.groupby(['Category']).agg({'Price': 'sum'})
##df2['Percentage'] = df2.groupby(level=0).apply(lambda x: 100 * x / x.sum())
# Percentage by lambda and DataFrame.apply() method
##df3 = df2.groupby(level=0).apply(lambda x:100 * x / float(x.sum()))
print(df2)
# Out:
#               Price
# Category
# Electronics  2533.0
# Furniture    1688.0
# Stationery     37.3

# %%
##print(df[['OrderID', 'O_date', 'OrderDate','month_name']])

set(df['Country'])
# Out:
# {'Argentina',
#  'Australia',
#  'Brazil',
#  'Canada',
#  'China',
#  'Colombia',
#  'Egypt',
#  'France',
#  'Germany',
#  'India',
#  'Iran',
#  'Italy',
#  'Japan',
#  'Mexico',
#  'Morocco',
#  'Pakistan',
#  'Poland',
#  'Portugal',
#  'Russia',
#  'Saudi Arabia',
#  'Singapore',
#  'South Korea',
#  'Spain',
#  'Sweden',
#  'UAE',
#  'UK',
#  'USA',
#  'Ukraine'}

# %%
df2 = df.groupby(['Category']).agg({'Price': 'sum'})
##print(df2)
##df2["perc"] = df2.groupby(level=0).apply(lambda x: 100 * x / x.sum())
##df2["perc"] = df2 / df["Price"]
##df2

# %%
df['Store_Sales_Pct'] = (
    df['Price'] / df.groupby('Category')['Price'].transform('sum')
) * 100

print("\nDataFrame with Percentage:")
print(df['Store_Sales_Pct'])

# %%
df['Country'].value_counts()

# %%
df2 = df.groupby(['Category', 'Fee']).agg({'Fee': 'sum'})
Courses = df.groupby(['Category']).agg({'Fee': 'sum'})
df2.div(Courses, level='Category') * 100

# %%
df.groupby(['Category','Store_Sales_Pct'])["Price"].sum()
